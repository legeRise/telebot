# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: python-telegram-bot==13.13 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (13.13)
# Requirement already satisfied: yt-dlp==2023.9.24 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (2023.9.24)
# Requirement already satisfied: google-api-python-client==1.12.8 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (1.12.8)
# Requirement already satisfied: certifi in /shared-libs/python3.9/py/lib/python3.9/site-packages (from python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (6.2)
# Requirement already satisfied: cachetools==4.2.2 in /root/venv/lib/python3.9/site-packages (from python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: APScheduler==3.6.3 in /root/venv/lib/python3.9/site-packages (from python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (3.6.3)
# Requirement already satisfied: pytz>=2018.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: websockets in /root/venv/lib/python3.9/site-packages (from yt-dlp==2023.9.24->-r ./requirements.txt (line 2)) (11.0.3)
# Requirement already satisfied: mutagen in /root/venv/lib/python3.9/site-packages (from yt-dlp==2023.9.24->-r ./requirements.txt (line 2)) (1.47.0)
# Requirement already satisfied: brotli in /root/venv/lib/python3.9/site-packages (from yt-dlp==2023.9.24->-r ./requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: pycryptodomex in /shared-libs/python3.9/py/lib/python3.9/site-packages (from yt-dlp==2023.9.24->-r ./requirements.txt (line 2)) (3.15.0)
# Requirement already satisfied: six<2dev,>=1.13.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /root/venv/lib/python3.9/site-packages (from google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /root/venv/lib/python3.9/site-packages (from google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (0.22.0)
# Requirement already satisfied: google-auth>=1.16.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (2.21.0)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /root/venv/lib/python3.9/site-packages (from google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (1.34.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /root/venv/lib/python3.9/site-packages (from google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (0.1.1)
# Requirement already satisfied: tzlocal>=1.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from APScheduler==3.6.3->python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (4.2)
# Requirement already satisfied: setuptools>=0.7 in /root/venv/lib/python3.9/site-packages (from APScheduler==3.6.3->python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (58.1.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (2.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (1.56.4)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (3.19.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth>=1.16.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth>=1.16.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (4.9)
# Requirement already satisfied: urllib3<2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from google-auth>=1.16.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (1.26.12)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client==1.12.8->-r ./requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tzlocal>=1.2->APScheduler==3.6.3->python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (0.1.0.post0)
# Requirement already satisfied: tzdata in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.2->APScheduler==3.6.3->python-telegram-bot==13.13->-r ./requirements.txt (line 1)) (2022.5)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=46d531e5-18f6-4f3d-ba3f-213620ca4d15' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
